# %%
# 프로젝트 1
class Square:
    def __init__(self):
        self.bot_width = 0
        self.top_width = 0
        self.height = 0
        
    def router(self):
        what_square = input("평행사변형(1), 사다리꼴(2), 끝내려면(3)")
        
        return what_square            
        
    def par(self):
        while True:
            try:
                self.bot_width = float(input("가로? "))
                self.height = float(input("세로? "))
            except ValueError as e:
                print(f"잘못된 입력입니다. {e}")
            else:
                area = self.bot_width * self.height
                result = f"넓이는 {area}"
                break
        return result
    
    def trape(self):
        while True:
            try:
                self.bot_width, self.top_width = map(float, input("아랫변과 윗변? (ex 1, 2) ").split(","))
                self.height = float(input("세로? "))
            except ValueError as e:
                print(f"잘못된 입력입니다. {e}")
            else:
                if self.bot_width > self.top_width:
                    area = (self.bot_width * self.height) - (((self.bot_width - self.top_width) * self.height) / 2)
                    break
                else:
                    area = (self.top_width * self.height) - (((self.top_width - self.bot_width) * self.height) / 2)
                    break
        
        result = f"넓이는 {area}"
        
        return result

# %%
def run():
    global square_calc
    square_calc = Square()
    
    while True:
        try:
            router = square_calc.router().lower()
            
            if router == "1":
                print(square_calc.par())
            elif router == "2":
                print(square_calc.trape())
            elif router == "3":
                print("종료.")
                break
            else:
                raise ValueError("잘못된 명령어 입력.")
            
        except ValueError as e:
            print(f"다시 입력해주세요. ({e})")

run()
# Out:
# 종료.

# %%
# 프로젝트 2
# 프로젝트 2번의 지불, 주문표 작성 메서드를 적절하게 구현할 수 있다.
# 각각의 메서드가 에러 없이, 정상적으로 동작하였다.
# 프로젝트 2번에서 Kiosk 클래스를 생성하고, 주문, 추가 주문 메서드를 적절하게 구현할 수 있다.

menu_list = ["캬라멜 푸딩 (1)", "와인 푸딩 (2)", "초코 푸딩 (3)"]
price_list = [6000, 8000, 7000]
temperature_option_list = ["Hot (1)", "Cold (2)"]
takeout_option_list = ["Store (1)", "Take out (2)"]
billing_option = ["현금 (1)", "카드 (2)"]

class Menu:
    def __init__(self, menu, price):
        self.menu_list = menu
        self.price_list = price
        
        
class Order:
    def __init__(self, temperature_option, takeout_option, billing_option):
        self.temperature_option = temperature_option
        self.takeout_option = takeout_option
        self.billing_option = billing_option

    
class Kiosk:
    def __init__(self):
        self.menu_number = 0
        self.temperature_number = 0
        self.takeout_number = 0
    
    def menu_order(self):
        menu_number = int(input("메뉴 번호를 입력해주세요.")) - 1
        return menu_number
            
    def temperature_order(self):
        temperature_number = int(input("온도 번호를 입력해주세요.")) - 1
        return temperature_number
    
    def takeout_order(self):
        takeout_number = int(input("테이크아웃 옵션 번호를 입력해주세요.")) - 1
        return takeout_number
    
    def billing_option(self):
        billing_number = int(input("지불 방식 번호를 입력해주세요.")) - 1
        return billing_number
    
    def run(self):
        while True:
            self.menu_order()
            self.temperature_order()
            self.takeout_order()
            self.billing_option()
            result =    
    
    def check(self):
        check_list = []
        
    
    def run():

# %%
a = Order()
a.menu()
# Out:
# ('와인 푸딩 (2)', 8000)
